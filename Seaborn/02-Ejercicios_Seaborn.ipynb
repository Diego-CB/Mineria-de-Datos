# %% [markdown]
# # Ejercicios básicos con Seaborn

# %% [markdown]
# ## Importar librerías

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importar Datos

# %%
tips = sns.load_dataset('tips')

# %% [markdown]
# ## Crear un histograma

# %%
sns.histplot(tips['total_bill'])
plt.show()

# %% [markdown]
# ## Crear una gráfica de dispersión

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.show()

# %% [markdown]
# ## Crear una gráfica de líneas

# %%
sns.lineplot(x='total_bill', y='tip', data=tips)
plt.show()

# %% [markdown]
# ## Crear una gráfica de barras

# %%
sns.barplot(x='day', y='total_bill', data=tips)
plt.show()

# %% [markdown]
# ## Crear una gráfica de caja con bigotes

# %%
sns.boxplot(x='day', y='total_bill', data=tips)
plt.show()

# %% [markdown]
# ## Crear una gráfica de violín

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
plt.show()

# %% [markdown]
# ## Crear un mapa de calor
#
# ### Ojo! se usan otros datos

# %%
flights = sns.load_dataset('flights')
flights = flights.pivot('month', 'year', 'passengers')
sns.heatmap(flights)
plt.show()
# Out:
# C:\Users\cordo\AppData\Local\Temp\ipykernel_1300\2608514826.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights = flights.pivot('month', 'year', 'passengers')

# %% [markdown]
# ## Crear gráficas de pares

# %%
sns.pairplot(tips)
plt.show()

# %% [markdown]
# ## Crear una gráfica de facetas

# %%
g = sns.FacetGrid(tips, col='time')
g.map(sns.histplot, 'total_bill')
plt.show()
# Out:
# d:\Archivos de programa\Python\3.10\lib\site-packages\seaborn\axisgrid.py:703: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# d:\Archivos de programa\Python\3.10\lib\site-packages\seaborn\axisgrid.py:703: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]

# %% [markdown]
# ## Crear una gráfica combinada "jointplot"

# %%
sns.jointplot(x='total_bill', y='tip', data=tips)
plt.show()

# %% [markdown]
# ## Crear una gráfica de categorías en una malla de facetas

# %%
sns.catplot(x='day', y='total_bill', hue='sex', kind='swarm', data=tips)
plt.show()

# %% [markdown]
# ## Creación de una gráfica de modelo lineal

# %%
sns.lmplot(x='total_bill', y='tip', data=tips)
plt.show()

# %% [markdown]
# ## Crear un histograma

# %%
sns.histplot(tips['total_bill'])
plt.savefig('total_bill_histogram.png')

# %% [markdown]
# ## Guardar una gráfica

# %%
hist = sbo.Histogram(data=tips, x='total_bill')
hist.plot()
plt.savefig('total_bill_histogram.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\GitHub\Mineria-de-Datos\Seaborn\02-Ejercicios_Seaborn.ipynb Cell 33 in <module>
# ----> <a href='vscode-notebook-cell:/d%3A/GitHub/Mineria-de-Datos/Seaborn/02-Ejercicios_Seaborn.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> hist = sbo.Histogram(data=tips, x='total_bill')
#       <a href='vscode-notebook-cell:/d%3A/GitHub/Mineria-de-Datos/Seaborn/02-Ejercicios_Seaborn.ipynb#X44sZmlsZQ%3D%3D?line=1'>2</a> hist.plot()
#       <a href='vscode-notebook-cell:/d%3A/GitHub/Mineria-de-Datos/Seaborn/02-Ejercicios_Seaborn.ipynb#X44sZmlsZQ%3D%3D?line=2'>3</a> plt.savefig('total_bill_histogram.png')
#
# NameError: name 'sbo' is not defined

# %% [markdown]
# ### Esta hoja de trabajo cubre algunas de las gráficas de Seaborn. Puede probar estos ejemplos y explorar otras funciones de Seaborn para crear visualizaciones más sofisticadas.
